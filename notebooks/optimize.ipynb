# %%
# ルートに移動

# %cd ..

# %%
# ライブラリのインポート

import os

from ultralytics.utils.torch_utils import strip_optimizer

# %%
# モデルの最適化

model_path = os.path.join("runs", "exp", "weights", "epoch70.pt")
save_path = os.path.join("submit", "model", "best.pt")

strip_optimizer(model_path, save_path)
